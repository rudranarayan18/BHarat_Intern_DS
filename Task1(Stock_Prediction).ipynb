# %% [markdown]
# #Stock Price predicton

# %% [markdown]
# ##PURPOSE : TO PREDICT THE STOCK PRICE OF A COMPANY USING LSTM.

# %% [markdown]
# About the dataset:Google stock predicton

# %% [markdown]
# ##Author :Rudranarayan Baral

# %% [markdown]
# *About the task*: Take stock price of any company you
# want and predicts its price by using LSTM.
# Use only Jupyter notebook code.

# %% [markdown]
# #Step 1: Importing library and data to be used

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('GOOG.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# #Step 2-Gathering Insights

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
#Summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
#Checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# Here there is no null value in this dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

#fig.show()

# %% [markdown]
# #Step 3: Data Pre-Processing

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# #Step 4: Creating LSTM model

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 11s 92ms/step - loss: 0.0086 - mean_absolute_error: 0.0676 - val_loss: 0.0260 - val_mean_absolute_error: 0.1367
# Epoch 2/100
# 28/28 [==============================] - 2s 54ms/step - loss: 9.1350e-04 - mean_absolute_error: 0.0247 - val_loss: 0.0078 - val_mean_absolute_error: 0.0677
# Epoch 3/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.8059e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0056 - val_mean_absolute_error: 0.0579
# Epoch 4/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.4284e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0054 - val_mean_absolute_error: 0.0565
# Epoch 5/100
# 28/28 [==============================] - 2s 83ms/step - loss: 3.9937e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0059 - val_mean_absolute_error: 0.0602
# Epoch 6/100
# 28/28 [==============================] - 2s 84ms/step - loss: 4.0944e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0064 - val_mean_absolute_error: 0.0629
# Epoch 7/100
# 28/28 [==============================] - 2s 83ms/step - loss: 4.4103e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0046 - val_mean_absolute_error: 0.0521
# Epoch 8/100
# 28/28 [==============================] - 3s 109ms/step - loss: 4.0937e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0063 - val_mean_absolute_error: 0.0634
# Epoch 9/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.9536e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0046 - val_mean_absolute_error: 0.0525
# Epoch 10/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.6421e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0040 - val_mean_absolute_error: 0.0487
# Epoch 11/100
# 28/28 [==============================] - 2s 87ms/step - loss: 3.5252e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0047 - val_mean_absolute_error: 0.0537
# Epoch 12/100
# 28/28 [==============================] - 2s 68ms/step - loss: 3.4319e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 13/100
# 28/28 [==============================] - 2s 72ms/step - loss: 3.6775e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0064 - val_mean_absolute_error: 0.0663
# Epoch 14/100
# 28/28 [==============================] - 2s 69ms/step - loss: 3.9311e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0024 - val_mean_absolute_error: 0.0365
# Epoch 15/100
# 28/28 [==============================] - 2s 77ms/step - loss: 3.9860e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0067 - val_mean_absolute_error: 0.0676
# Epoch 16/100
# 28/28 [==============================] - 3s 92ms/step - loss: 3.3866e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0051 - val_mean_absolute_error: 0.0577
# Epoch 17/100
# 28/28 [==============================] - 3s 92ms/step - loss: 3.1501e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0055 - val_mean_absolute_error: 0.0607
# Epoch 18/100
# 28/28 [==============================] - 3s 105ms/step - loss: 3.1218e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0029 - val_mean_absolute_error: 0.0410
# Epoch 19/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.9417e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0023 - val_mean_absolute_error: 0.0364
# Epoch 20/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.1703e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0053 - val_mean_absolute_error: 0.0601
# Epoch 21/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.6777e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 22/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.7615e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0049 - val_mean_absolute_error: 0.0562
# Epoch 23/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.6592e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0036 - val_mean_absolute_error: 0.0474
# Epoch 24/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.6217e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0019 - val_mean_absolute_error: 0.0321
# Epoch 25/100
# 28/28 [==============================] - 2s 80ms/step - loss: 2.7123e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0043 - val_mean_absolute_error: 0.0523
# Epoch 26/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.8275e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0045 - val_mean_absolute_error: 0.0547
# Epoch 27/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.7063e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0037 - val_mean_absolute_error: 0.0480
# Epoch 28/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.3799e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0037 - val_mean_absolute_error: 0.0487
# Epoch 29/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.3052e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0044 - val_mean_absolute_error: 0.0533
# Epoch 30/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.6387e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0020 - val_mean_absolute_error: 0.0328
# Epoch 31/100
# 28/28 [==============================] - 3s 100ms/step - loss: 2.8121e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 32/100
# 28/28 [==============================] - 3s 91ms/step - loss: 2.3320e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0023 - val_mean_absolute_error: 0.0363
# Epoch 33/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.1612e-04 - mean_absolute_error: 0.0108 - val_loss: 9.5902e-04 - val_mean_absolute_error: 0.0226
# Epoch 34/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2038e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0022 - val_mean_absolute_error: 0.0358
# Epoch 35/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2175e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0040 - val_mean_absolute_error: 0.0521
# Epoch 36/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1840e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309
# Epoch 37/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.0945e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0043 - val_mean_absolute_error: 0.0541
# Epoch 38/100
# 28/28 [==============================] - 4s 151ms/step - loss: 2.2481e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 39/100
# 28/28 [==============================] - 3s 124ms/step - loss: 1.7951e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 40/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.9076e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0025 - val_mean_absolute_error: 0.0405
# Epoch 41/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.8892e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 42/100
# 28/28 [==============================] - 5s 166ms/step - loss: 1.9134e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 43/100
# 28/28 [==============================] - 3s 106ms/step - loss: 1.7627e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 44/100
# 28/28 [==============================] - 3s 114ms/step - loss: 1.7509e-04 - mean_absolute_error: 0.0096 - val_loss: 9.3237e-04 - val_mean_absolute_error: 0.0226
# Epoch 45/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7372e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0020 - val_mean_absolute_error: 0.0366
# Epoch 46/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.0600e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 47/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6622e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 48/100
# 28/28 [==============================] - 3s 92ms/step - loss: 1.5952e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0021 - val_mean_absolute_error: 0.0374
# Epoch 49/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.6125e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 50/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6929e-04 - mean_absolute_error: 0.0093 - val_loss: 5.2145e-04 - val_mean_absolute_error: 0.0169
# Epoch 51/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6493e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 52/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7584e-04 - mean_absolute_error: 0.0096 - val_loss: 8.2435e-04 - val_mean_absolute_error: 0.0216
# Epoch 53/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.6173e-04 - mean_absolute_error: 0.0091 - val_loss: 7.1312e-04 - val_mean_absolute_error: 0.0201
# Epoch 54/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4730e-04 - mean_absolute_error: 0.0085 - val_loss: 9.0037e-04 - val_mean_absolute_error: 0.0231
# Epoch 55/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.4037e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0322
# Epoch 56/100
# 28/28 [==============================] - 2s 86ms/step - loss: 1.6991e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 57/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3480e-04 - mean_absolute_error: 0.0084 - val_loss: 8.0981e-04 - val_mean_absolute_error: 0.0214
# Epoch 58/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5153e-04 - mean_absolute_error: 0.0089 - val_loss: 9.4657e-04 - val_mean_absolute_error: 0.0238
# Epoch 59/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3166e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0014 - val_mean_absolute_error: 0.0305
# Epoch 60/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3144e-04 - mean_absolute_error: 0.0080 - val_loss: 8.1074e-04 - val_mean_absolute_error: 0.0220
# Epoch 61/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4099e-04 - mean_absolute_error: 0.0086 - val_loss: 3.8542e-04 - val_mean_absolute_error: 0.0146
# Epoch 62/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4418e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8480e-04 - val_mean_absolute_error: 0.0147
# Epoch 63/100
# 28/28 [==============================] - 4s 135ms/step - loss: 1.4131e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0020 - val_mean_absolute_error: 0.0382
# Epoch 64/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3776e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0021 - val_mean_absolute_error: 0.0392
# Epoch 65/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.2564e-04 - mean_absolute_error: 0.0081 - val_loss: 8.9926e-04 - val_mean_absolute_error: 0.0231
# Epoch 66/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0079 - val_loss: 6.8575e-04 - val_mean_absolute_error: 0.0201
# Epoch 67/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.3062e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0013 - val_mean_absolute_error: 0.0288
# Epoch 68/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2607e-04 - mean_absolute_error: 0.0079 - val_loss: 8.1538e-04 - val_mean_absolute_error: 0.0226
# Epoch 69/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.1736e-04 - mean_absolute_error: 0.0077 - val_loss: 4.0905e-04 - val_mean_absolute_error: 0.0152
# Epoch 70/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.2241e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 71/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.0890e-04 - mean_absolute_error: 0.0074 - val_loss: 8.2642e-04 - val_mean_absolute_error: 0.0222
# Epoch 72/100
# 28/28 [==============================] - 3s 99ms/step - loss: 1.2126e-04 - mean_absolute_error: 0.0078 - val_loss: 7.7942e-04 - val_mean_absolute_error: 0.0218
# Epoch 73/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.1224e-04 - mean_absolute_error: 0.0077 - val_loss: 9.3909e-04 - val_mean_absolute_error: 0.0243
# Epoch 74/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.2065e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0010 - val_mean_absolute_error: 0.0265
# Epoch 75/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.1845e-04 - mean_absolute_error: 0.0078 - val_loss: 3.7532e-04 - val_mean_absolute_error: 0.0143
# Epoch 76/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.2069e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0014 - val_mean_absolute_error: 0.0323
# Epoch 77/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2221e-04 - mean_absolute_error: 0.0080 - val_loss: 4.6584e-04 - val_mean_absolute_error: 0.0163
# Epoch 78/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2431e-04 - mean_absolute_error: 0.0080 - val_loss: 6.9574e-04 - val_mean_absolute_error: 0.0207
# Epoch 79/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1216e-04 - mean_absolute_error: 0.0075 - val_loss: 3.6128e-04 - val_mean_absolute_error: 0.0143
# Epoch 80/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.0328e-04 - mean_absolute_error: 0.0073 - val_loss: 4.4296e-04 - val_mean_absolute_error: 0.0158
# Epoch 81/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.0871e-04 - mean_absolute_error: 0.0073 - val_loss: 6.4230e-04 - val_mean_absolute_error: 0.0203
# Epoch 82/100
# 28/28 [==============================] - 3s 101ms/step - loss: 9.9764e-05 - mean_absolute_error: 0.0069 - val_loss: 4.0648e-04 - val_mean_absolute_error: 0.0153
# Epoch 83/100
# 28/28 [==============================] - 3s 100ms/step - loss: 1.1300e-04 - mean_absolute_error: 0.0074 - val_loss: 5.1636e-04 - val_mean_absolute_error: 0.0178
# Epoch 84/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.0786e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0902e-04 - val_mean_absolute_error: 0.0129
# Epoch 85/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.0827e-04 - mean_absolute_error: 0.0073 - val_loss: 7.0922e-04 - val_mean_absolute_error: 0.0223
# Epoch 86/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2015e-04 - mean_absolute_error: 0.0080 - val_loss: 3.5723e-04 - val_mean_absolute_error: 0.0141
# Epoch 87/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.0947e-04 - mean_absolute_error: 0.0072 - val_loss: 3.5673e-04 - val_mean_absolute_error: 0.0138
# Epoch 88/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2432e-04 - mean_absolute_error: 0.0080 - val_loss: 4.1161e-04 - val_mean_absolute_error: 0.0153
# Epoch 89/100
# 28/28 [==============================] - 4s 133ms/step - loss: 1.0255e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5363e-04 - val_mean_absolute_error: 0.0115
# Epoch 90/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.0357e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0125
# Epoch 91/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0345e-04 - mean_absolute_error: 0.0069 - val_loss: 3.5151e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.0337e-04 - mean_absolute_error: 0.0071 - val_loss: 5.4947e-04 - val_mean_absolute_error: 0.0189
# Epoch 93/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0078e-04 - mean_absolute_error: 0.0070 - val_loss: 2.6409e-04 - val_mean_absolute_error: 0.0118
# Epoch 94/100
# 28/28 [==============================] - 4s 157ms/step - loss: 1.0490e-04 - mean_absolute_error: 0.0070 - val_loss: 3.3160e-04 - val_mean_absolute_error: 0.0134
# Epoch 95/100
# 28/28 [==============================] - 4s 145ms/step - loss: 1.2620e-04 - mean_absolute_error: 0.0082 - val_loss: 2.7947e-04 - val_mean_absolute_error: 0.0124
# Epoch 96/100
# 28/28 [==============================] - 4s 155ms/step - loss: 9.9451e-05 - mean_absolute_error: 0.0071 - val_loss: 2.7397e-04 - val_mean_absolute_error: 0.0122
# Epoch 97/100
# 28/28 [==============================] - 4s 154ms/step - loss: 1.0173e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7431e-04 - val_mean_absolute_error: 0.0122
# Epoch 98/100
# 28/28 [==============================] - 3s 120ms/step - loss: 1.0566e-04 - mean_absolute_error: 0.0072 - val_loss: 2.6100e-04 - val_mean_absolute_error: 0.0118
# Epoch 99/100
# 28/28 [==============================] - 3s 98ms/step - loss: 9.1553e-05 - mean_absolute_error: 0.0065 - val_loss: 4.2475e-04 - val_mean_absolute_error: 0.0156
# Epoch 100/100
# 28/28 [==============================] - 2s 55ms/step - loss: 8.9727e-05 - mean_absolute_error: 0.0065 - val_loss: 2.7251e-04 - val_mean_absolute_error: 0.0120

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 18ms/step
# array([[0.4030131 , 0.4013764 ],
#        [0.40306622, 0.4012936 ],
#        [0.3998092 , 0.3979121 ],
#        [0.40518653, 0.40350574],
#        [0.40852216, 0.40682775]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1418.154 , 1412.147 ],
#        [1418.2526, 1411.9935],
#        [1412.2142, 1405.7264],
#        [1422.1835, 1416.0934],
#        [1428.3673, 1422.2501]], dtype=float32)

# %% [markdown]
# #step 5: Data Visualizing (Actual VS Predicted Data)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1418.154053      1412.146973
# 2020-05-28  1396.86  1416.73     1418.252563      1411.993530
# 2020-05-29  1416.94  1428.92     1412.214233      1405.726440
# 2020-06-01  1418.39  1431.82     1422.183472      1416.093384
# 2020-06-02  1430.55  1439.22     1428.367310      1422.250122

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %% [markdown]
# #STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2496.846924      2488.696045
# 2021-06-10  2494.01  2521.60     2507.491699      2499.785889
# 2021-06-11  2524.92  2513.93     2533.502930      2526.639160
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
# inversing Normalization/scaling

upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
